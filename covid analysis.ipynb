# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('onedork')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #b5c2d9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #899ab8;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d1e23;
#  background: #1d1e23;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #899ab8;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #bbc2e0;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
## The data set was obtained from kaggle.com
## Covid-19 worldwide data by akash kunwar, obtained on the 23/02/2022

# %% [markdown]
# ## Importing the data set

# %%
import pandas as pd
import seaborn as sns

# %%
covidData = pd.read_csv('Covid data.csv')

# %%
covidData
# Out:
#               Date      Country  Total cases  Total deaths  New cases  \
# 0       2020-01-22  Afghanistan            0             0          0
# 1       2020-01-23  Afghanistan            0             0          0
# 2       2020-01-24  Afghanistan            0             0          0
# 3       2020-01-25  Afghanistan            0             0          0
# 4       2020-01-26  Afghanistan            0             0          0
# ...            ...          ...          ...           ...        ...
# 208595  2022-01-31     Zimbabwe       229666          5338        206
# 208596  2022-02-01     Zimbabwe       229851          5350        185
# 208597  2022-02-02     Zimbabwe       230012          5352        161
# 208598  2022-02-03     Zimbabwe       230170          5357        158
# 208599  2022-02-04     Zimbabwe       230170          5357          0
#
#         New deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
covidData.ndim
# Out:
# 2

# %%
covidData.isnull().sum()
# Out:
# Date            0
# Country         0
# Total cases     0
# Total deaths    0
# New cases       0
# New deaths      0
# dtype: int64

# %%
covidData.size
# Out:
# 1251600

# %%
covidData.shape
# Out:
# (208600, 6)

# %%
covidData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208600 entries, 0 to 208599
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          208600 non-null  object
#  1   Country       208600 non-null  object
#  2   Total cases   208600 non-null  int64
#  3   Total deaths  208600 non-null  int64
#  4   New cases     208600 non-null  int64
#  5   New deaths    208600 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 9.5+ MB

# %%
covidData.describe()
# Out:
#         Total cases   Total deaths     New cases     New deaths
# count  2.086000e+05  208600.000000  2.086000e+05  208600.000000
# mean   4.149234e+05    8802.100594  1.879969e+03      27.515168
# std    2.477202e+06   45407.685195  1.485543e+04     157.384942
# min    0.000000e+00       0.000000  0.000000e+00       0.000000
# 25%    2.140000e+02       2.000000  0.000000e+00       0.000000
# 50%    4.396000e+03      63.000000  7.000000e+00       0.000000
# 75%    8.658075e+04    1474.000000  3.200000e+02       4.000000
# max    7.635404e+07  901391.000000  1.369637e+06    8786.000000

# %%
## The data set has 208600 rows and 6 columns
## its a 2 dimentional data
## There are no null/empty fields
## There are three types of data sets ---- integers, strings, data(if its classified)
## else there are only two ---- integers and objects

# %%
covidData.groupby('Country').size()
# Out:
# Country
# Afghanistan    745
# Albania        745
# Alberta        745
# Algeria        745
# Andorra        745
#               ...
# Yukon          745
# Yunnan         745
# Zambia         745
# Zhejiang       745
# Zimbabwe       745
# Length: 279, dtype: int64

# %%
## there are 279 countries sets in the data sets
## there six which are not countries which will make the orginal country count to be 273
## out of the six non countries 3 of them are cruise ships, 1 is an event and the, 1 is for travellers and the other
## unknown
## the unknown country data will be invalid in our research

# %%
sns.barplot(x='Country',y='Total cases', data=covidData)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Total cases'>

# %%
#africa
#north america
#south america
#europe
#asia
#austrialia
#antarctica

# %% [markdown]
# #africa----
# Algeria,
# Egypt,
# Liberia,
# Libya,
# Morocco,
# Sudan,
# Tunisia,
# Benin,
# Burkina Faso,
# Cote d'Ivoire,
# Gambia,
# Ghana,
# Guinea,
# Guinea-Bissau,
# Mali,
# Mauritania,
# Niger,
# Nigeria,
# Saint Helena, Ascension and Tristan da Cunha,
# Senegal,
# Sierra Leone,
# Togo,
# Angola,
# Cameroon,
# Central African Republic,
# Chad,
# Congo (Brazzaville),
# Congo (Kinshasa),
# Equatorial Guinea,
# Gabon,
# Sao Tome and Principe,
# Burundi,
# Comoros,
# Djibouti,
# Eritrea,
# Ethiopia,
# Kenya,
# Madagascar,
# Malawi,
# Mauritius,
# Mozambique,
# Reunion,
# Rwanda,
# Seychelles,
# Somalia,
# South Sudan,
# Tanzania,
# Uganda,
# Zambia,
# Zimbabwe,
# Botswana,
# Lesotho,
# Namibia,
# South Africa,
# Cabo Verde,
# Eswatini,
# Mayotte

# %% [markdown]
# #america----
# Greenland
# Mexico
# US
# Anguilla
# Antigua and Barbuda
# Aruba
# Bahamas
# Barbados
# Bermuda
# British Virgin Islands
# Cayman Islands
# Cuba
# Curacao
# Dominica
# Dominican Republic
# Grenada
# Guadeloupe
# Haiti
# Jamaica
# Martinique
# Montserrat
# Saint Kitts and Nevis
# Saint Lucia
# Saint Vincent and the Grenadines
# Trinidad and Tobago
# Belize
# Costa Rica
# El Salvador
# Guatemala
# Honduras
# Nicaragua
# Panama
# Argentina
# Bolivia
# Brazil
# Chile
# Colombia
# Ecuador
# French Guiana
# Guyana
# Paraguay
# Peru
# Suriname
# Uruguay
# Venezuela
# Alberta
# Bonaire, Sint Eustatius and Saba
# British Columbia
# Falkland Islands (Malvinas)
# Manitoba
# New Brunswick
# Newfoundland and Labrador
# Northwest Territories
# Nova Scotia
# Nunavut
# Ontario
# Prince Edward Island
# Quebec
# Saint Barthelemy
# Saint Pierre and Miquelon
# Saskatchewan
# St Martin
# Turks and Caicos Islands
# Yukon

# %% [markdown]
# #asia----
# Russia
# Armenia
# Azerbaijan
# Bahrain
# Cyprus
# Georgia
# Iran
# Iraq
# Israel
# Jordan
# Kuwait
# Lebanon
# Oman
# Qatar
# Saudi Arabia
# Syria
# Turkey
# United Arab Emirates
# Yemen
# Afghanistan
# Kazakhstan
# Kyrgyzstan
# Tajikistan
# Uzbekistan
# Japan
# Korea, South
# Mongolia
# Taiwan*
# Bangladesh
# Bhutan
# India
# Maldives
# Nepal
# Pakistan
# Sri Lanka
# Brunei
# Cambodia
# Indonesia
# Malaysia
# Philippines
# Singapore
# Thailand
# Timor-Leste
# Vietnam
# Anhui
# Beijing
# Burma
# Chongqing
# Fujian
# Gansu
# Guangdong
# Guangxi
# Guizhou
# Hainan
# Hebei
# Heilongjiang
# Henan
# Hong Kong
# Hubei
# Hunan
# Inner Mongolia
# Jiangsu
# Jiangxi
# Jilin
# Laos
# Liaoning
# Macau
# Ningxia
# Qinghai
# Shaanxi
# Shandong
# Shanghai
# Shanxi
# Sichuan
# Tianjin
# Tibet
# West Bank and Gaza
# Xinjiang
# Yunnan
# Zhejiang

# %% [markdown]
# #austrialia----
# Australian Capital Territory
# New Zealand
# Fiji
# New Caledonia
# Papua New Guinea
# Solomon Islands
# Vanuatu
# Kiribati
# Marshall Islands
# Micronesia
# Palau
# Cook Islands
# French Polynesia
# Samoa
# Tonga
# New South Wales
# Northern Territory
# Queensland
# South Australia
# Tasmania
# Victoria
# Wallis and Futuna
# Western Australia

# %% [markdown]
# #europe----
# Denmark
# Estonia
# Faroe Islands
# Finland
# Iceland
# Ireland
# Latvia
# Lithuania
# Norway
# Sweden
# United Kingdom
# Austria
# Belgium
# France
# Germany
# Liechtenstein
# Luxembourg
# Netherlands
# Switzerland
# Belarus
# Bulgaria
# Czechia
# Hungary
# Moldova
# Poland
# Romania
# Slovakia
# Ukraine
# Albania
# Andorra
# Bosnia and Herzegovina
# Croatia
# Gibraltar
# Greece
# Italy
# Kosovo
# North Macedonia
# Malta
# Monaco
# Montenegro
# Portugal
# San Marino
# Serbia
# Slovenia
# Spain
# Channel Islands
# Holy See
# Isle of Man
# Sint Maarten

# %% [markdown]
# #antarctica-----

# %% [markdown]
# #non continents----
# Diamond Princess//ship
# Grand Princess//ship
# MS Zaandam//ship
# Repatriated Travellers
# Summer Olympics 2020
# Unknown

# %%
##eleminating non countries

# %%
dataTWO = pd.read_csv('Covid data.csv')
//CD = dataTWO.groupby('Country').sum()
# Out:
#   File "<ipython-input-449-a673bffd0a31>", line 2
#     //CD = dataTWO.groupby('Country').sum()
#     ^
# SyntaxError: invalid syntax

# %%
dataTWO
# Out:
#               Date      Country  Total cases  Total deaths  New cases  \
# 0       2020-01-22  Afghanistan            0             0          0
# 1       2020-01-23  Afghanistan            0             0          0
# 2       2020-01-24  Afghanistan            0             0          0
# 3       2020-01-25  Afghanistan            0             0          0
# 4       2020-01-26  Afghanistan            0             0          0
# ...            ...          ...          ...           ...        ...
# 208595  2022-01-31     Zimbabwe       229666          5338        206
# 208596  2022-02-01     Zimbabwe       229851          5350        185
# 208597  2022-02-02     Zimbabwe       230012          5352        161
# 208598  2022-02-03     Zimbabwe       230170          5357        158
# 208599  2022-02-04     Zimbabwe       230170          5357          0
#
#         New deaths
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...

# %%
##dataTWO.columns = dataTWO.columns.str.replace(' ','_')

# %%
data = pd.read_csv("Covid data.csv", index_col ="Country" )

# %%
data.drop(["Diamond Princess", "Grand Princess", "MS Zaandam","Repatriated Travellers","Summer Olympics 2020","Unknown"], inplace = True)

# %%
data
# Out:
#                    Date  Total cases  Total deaths  New cases  New deaths
# Country
# Afghanistan  2020-01-22            0             0          0           0
# Afghanistan  2020-01-23            0             0          0           0
# Afghanistan  2020-01-24            0             0          0           0
# Afghanistan  2020-01-25            0             0          0           0
# Afghanistan  2020-01-26            0             0          0           0
# ...                 ...          ...           ...        ...         ...
# Zimbabwe     2022-01-31       229666          5338        206           1
# Zimbabwe     2022-02-01       229851          5350        185          12
# Zimbabwe     2022-02-02       230012          5352        161           2
# Zimbabwe     2022-02-03       230170          5357        158           5
# Zimbabwe     2022-02-04       230170          5357          0           0
#
# [203385 rows x 5 columns]

# %%
##grouping the countries together

# %%
covidDataCountryGrouped = data.groupby('Country').sum()

# %%
covidDataCountryGrouped.columns = covidDataCountryGrouped.columns.str.replace(' ','_')

# %%
covidDataCountryGrouped
# Out:
#              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Afghanistan     53616281       2333935     165366        7420
# Albania         63095851       1074529     263172        3371
# Alberta        104954264       1052011     503434        3652
# Algeria         75918424       2167120     256806        6631
# Andorra          6844415         65135      36599         147
# ...                  ...           ...        ...         ...
# Yukon             284044          2644       3186          18
# Yunnan            420561          1433       1883           2
# Zambia          65248213       1037917     306777        3928
# Zhejiang         1014258           716       2228           1
# Zimbabwe        39286321       1249449     230176        5357
#
# [273 rows x 4 columns]

# %%
covidData.groupby('Country').size()
# Out:
# Country
# Afghanistan    745
# Albania        745
# Alberta        745
# Algeria        745
# Andorra        745
#               ...
# Yukon          745
# Yunnan         745
# Zambia         745
# Zhejiang       745
# Zimbabwe       745
# Length: 279, dtype: int64

# %%
covidData.Country.value_counts(normalize = True).plot(kind = "bar", figsize = (50,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # CHECKING FOR THE HIGHEST AND THE LOWEST COUNTRY IN RESPECT TO THE CASES AND DEATHS

# %%
covidDataCountryGrouped['Total_cases'].max()
# Out:
# 17333428258

# %%
covidDataCountryGrouped['New_cases'].max()
# Out:
# 76354039

# %%
covidDataCountryGrouped['Total_deaths'].max()
# Out:
# 301478150

# %%
covidDataCountryGrouped['New_deaths'].max()
# Out:
# 901391

# %%
##covidDataCountryGrouped.columns = covidDataCountryGrouped.columns.str.replace(' ','_')

# %%
covidDataCountryGrouped
# Out:
#              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Afghanistan     53616281       2333935     165366        7420
# Albania         63095851       1074529     263172        3371
# Alberta        104954264       1052011     503434        3652
# Algeria         75918424       2167120     256806        6631
# Andorra          6844415         65135      36599         147
# ...                  ...           ...        ...         ...
# Yukon             284044          2644       3186          18
# Yunnan            420561          1433       1883           2
# Zambia          65248213       1037917     306777        3928
# Zhejiang         1014258           716       2228           1
# Zimbabwe        39286321       1249449     230176        5357
#
# [273 rows x 4 columns]

# %%
highestCountryTotalCases = covidDataCountryGrouped[covidDataCountryGrouped.Total_cases == 17333428258]

# %%
highestCountryTotaldeaths = covidDataCountryGrouped[covidDataCountryGrouped.Total_deaths == 301478150]

# %%
highestCountryNewCases = covidDataCountryGrouped[covidDataCountryGrouped.New_cases == 76354039]

# %%
highestCountryNewdeaths = covidDataCountryGrouped[covidDataCountryGrouped.New_deaths == 901391]

# %%
highestCountryTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestCountryTotaldeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestCountryNewCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestCountryNewdeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
covidDataCountryGrouped['Total_cases'].min()
# Out:
# 114

# %%
covidDataCountryGrouped['New_cases'].min()
# Out:
# 1

# %%
covidDataCountryGrouped['Total_deaths'].min()
# Out:
# 0

# %%
covidDataCountryGrouped['New_deaths'].min()
# Out:
# 0

# %%
lowestCountryTotalCases = covidDataCountryGrouped[covidDataCountryGrouped.Total_cases == 114]

# %%
lowestCountryTotaldeaths = covidDataCountryGrouped[covidDataCountryGrouped.Total_deaths == 0]

# %%
lowestCountryNewCases = covidDataCountryGrouped[covidDataCountryGrouped.New_cases == 1]

# %%
lowestCountryNewdeaths = covidDataCountryGrouped[covidDataCountryGrouped.New_deaths == 0]

# %%
lowestCountryTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tonga            114             0          7           0

# %%
lowestCountryTotaldeaths
# Out:
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Cook Islands                         324             0          2           0
# Falkland Islands (Malvinas)        29537             0         93           0
# Holy See                           15265             0         29           0
# Jiangsu                           669575             0       1629           0
# Kiribati                            5739             0       1037           0
# Macau                              37716             0         78           0
# Marshall Islands                    1898             0          8           0
# Micronesia                           380             0          1           0
# Ningxia                            59706             0        121           0
# Palau                              20331             0       2352           0
# Qinghai                            14411             0         30           0
# ...

# %%
lowestCountryNewCases
# Out:
#             Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Micronesia          380             0          1           0
# Tibet               737             0          1           0

# %%
lowestCountryNewdeaths
# Out:
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Cook Islands                         324             0          2           0
# Falkland Islands (Malvinas)        29537             0         93           0
# Holy See                           15265             0         29           0
# Jiangsu                           669575             0       1629           0
# Kiribati                            5739             0       1037           0
# Macau                              37716             0         78           0
# Marshall Islands                    1898             0          8           0
# Micronesia                           380             0          1           0
# Ningxia                            59706             0        121           0
# Palau                              20331             0       2352           0
# Qinghai                            14411             0         30           0
# ...

# %% [markdown]
# # Grouping them by continents and finding the highest and lowest

# %%
##covidDataCountryGrouped.rows = covidDataCountryGrouped.rows.str.replace(' ','_')

# %%
covidDataCountryGrouped.loc[['Tibet','Marshall Islands','Holy See']]
# Out:
#                   Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet                     737             0          1           0
# Marshall Islands         1898             0          8           0
# Holy See                15265             0         29           0

# %%
##male = covidDataCountryGrouped[covidDataCountryGrouped.Country == 'Tonga']

# %%
##covidDataCountryGrouped.loc[(covidDataCountryGrouped.Country == 'Tonga')]

# %%
##spar.loc[[10103,10120,10102]]

# %%
africanContinent = covidDataCountryGrouped.loc[[
"Algeria",
"Egypt",
"Liberia",
"Libya",
"Morocco",
"Sudan",
"Tunisia",
"Benin",
"Burkina Faso",
"Cote d'Ivoire",
"Gambia",
"Ghana",
"Guinea",
"Guinea-Bissau",
"Mali",
"Mauritania",
"Niger",
"Nigeria",
"Saint Helena, Ascension and Tristan da Cunha",
"Senegal",
"Sierra Leone",
"Togo",
"Angola",
"Cameroon",
"Central African Republic",
"Chad",
"Congo (Brazzaville)",
"Congo (Kinshasa)",
"Equatorial Guinea",
"Gabon",
"Sao Tome and Principe",
"Burundi",
"Comoros",
"Djibouti",
"Eritrea",
"Ethiopia",
"Kenya",
"Madagascar",
"Malawi",
"Mauritius",
"Mozambique",
"Reunion",
"Rwanda",
"Seychelles",
"Somalia",
"South Sudan",
"Tanzania",
"Uganda",
"Zambia",
"Zimbabwe",
"Botswana",
"Lesotho",
"Namibia",
"South Africa",
"Cabo Verde",
"Eswatini",
"Mayotte"]]

# %%
africanContinent
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Algeria                                          75918424       2167120
# Egypt                                           131375680       7441513
# Liberia                                           1949444         87622
# Libya                                           108642375       1619079
# Morocco                                         313678883       5047545
# Sudan                                            17930854       1240185
# Tunisia                                         207339270       7112753
# Benin                                             5993976         54039
# Burkina Faso                                      6070395         92448
# Cote d'Ivoire                                    24122302        194223
# Gambia                                            3540568        112562
# Ghana                                            51468853        415981
# ...

# %%
austrialiaContinent = covidDataCountryGrouped.loc[[
"Australian Capital Territory",
"New Zealand",
"Fiji",
"New Caledonia",
"Papua New Guinea",
"Solomon Islands",
"Vanuatu",
"Kiribati",
"Marshall Islands",
"Micronesia",
"Palau",
"Cook Islands",
"French Polynesia",
"Samoa",
"Tonga",
"New South Wales",
"Northern Territory",
"Queensland",
"South Australia",
"Tasmania",
"Victoria",
"Wallis and Futuna",
"Western Australia"]]

# %%
austrialiaContinent
# Out:
#                               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Australian Capital Territory      1103219          3539      38306          30
# New Zealand                       2608859         18289      17551          53
# Fiji                             10185077        121499      63274         813
# New Caledonia                     1707772         34429      25781         284
# Papua New Guinea                  7220827         93437      37406         598
# Solomon Islands                     24008           102       2360          21
# Vanuatu                              1665           290          7           1
# Kiribati                             5739             0       1037           0
# Marshall Islands                     1898             0          8           0
# Micronesia                            380             0          1           0
# Palau                               20331             0       2352           0
# ...

# %%
europeContinent = covidDataCountryGrouped.loc[[
"Denmark",
"Estonia",
"Faroe Islands",
"Finland",
"Iceland",
"Ireland",
"Latvia",
"Lithuania",
"Norway",
"Sweden",
"United Kingdom",
"Austria",
"Belgium",
"France",
"Germany",
"Liechtenstein",
"Luxembourg",
"Netherlands",
"Switzerland",
"Belarus",
"Bulgaria",
"Czechia",
"Hungary",
"Moldova",
"Poland",
"Romania",
"Slovakia",
"Ukraine",
"Albania",
"Andorra",
"Bosnia and Herzegovina",
"Croatia",
"Gibraltar",
"Greece",
"Italy",
"Kosovo",
"North Macedonia",
"Malta",
"Monaco",
"Montenegro",
"Portugal",
"San Marino",
"Serbia",
"Slovenia",
"Spain",
"Channel Islands",
"Holy See",
"Isle of Man",
"Sint Maarten"]]

# %%
europeContinent
# Out:
#                         Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Denmark                   169977219       1218115    1929341        3834
# Estonia                    59636233        516363     366089        2062
# Faroe Islands               1020081          1630      22908          20
# Finland                    57867951        531945     514892        2058
# Iceland                     6051013         16486      73531          55
# Ireland                   167286974       2431433    1208820        6247
# Latvia                     65338440       1095667     432370        4934
# Lithuania                 133190820       1958363     727169        7952
# Norway                     79226878        410693     870245        1469
# Sweden                    449640500       7088061    2287785       16436
# United Kingdom           2947845708      63547499   17697109      157984
# Austria                   327207524       4612945    1995346       14206
# ...

# %%
asianContinent = covidDataCountryGrouped.loc[[
"Russia",
"Armenia",
"Azerbaijan",
"Bahrain",
"Cyprus",
"Georgia",
"Iran",
"Iraq",
"Israel",
"Jordan",
"Kuwait",
"Lebanon",
"Oman",
"Qatar",
"Saudi Arabia",
"Syria",
"Turkey",
"United Arab Emirates",
"Yemen",
"Afghanistan",
"Kazakhstan",
"Kyrgyzstan",
"Tajikistan",
"Uzbekistan",
"Japan",
"Korea, South",
"Mongolia",
"Taiwan*",
"Bangladesh",
"Bhutan",
"India",
"Maldives",
"Nepal",
"Pakistan",
"Sri Lanka",
"Brunei",
"Cambodia",
"Indonesia",
"Malaysia",
"Philippines",
"Singapore",
"Thailand",
"Timor-Leste",
"Vietnam",
"Anhui",
"Beijing",
"Burma",
"Chongqing",
"Fujian",
"Gansu",
"Guangdong",
"Guangxi",
"Guizhou",
"Hainan",
"Hebei",
"Heilongjiang",
"Henan",
"Hong Kong",
"Hubei",
"Hunan",
"Inner Mongolia",
"Jiangsu",
"Jiangxi",
"Jilin",
"Laos",
"Liaoning",
"Macau",
"Ningxia",
"Qinghai",
"Shaanxi",
"Shandong",
"Shanghai",
"Shanxi",
"Sichuan",
"Tianjin",
"Tibet",
"West Bank and Gaza",
"Xinjiang",
"Yunnan",
"Zhejiang"]]

# %%
asianContinent
# Out:
#                     Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Russia               2894992156      72161883   12257664      327310
# Armenia               113165774       2267337     383458        8077
# Azerbaijan            172580639       2352055     683476        8823
# Bahrain               103934353        467493     405938        1410
# Cyprus                 39936476        177604     268852         740
# ...                         ...           ...        ...         ...
# Tibet                       737             0          1           0
# West Bank and Gaza    141835244       1501821     556550        5128
# Xinjiang                 550212          2145        996           3
# Yunnan                   420561          1433       1883           2
# Zhejiang                1014258           716       2228           1
#
# [80 rows x 4 columns]

# %%
americanContinents = covidDataCountryGrouped.loc[[
"Greenland",
"Mexico",
"US",
"Anguilla",
"Antigua and Barbuda",
"Aruba",
"Bahamas",
"Barbados",
"Bermuda",
"British Virgin Islands",
"Cayman Islands",
"Cuba",
"Curacao",
"Dominica",
"Dominican Republic",
"Grenada",
"Guadeloupe",
"Haiti",
"Jamaica",
"Martinique",
"Montserrat",
"Saint Kitts and Nevis",
"Saint Lucia",
"Saint Vincent and the Grenadines",
"Trinidad and Tobago",
"Belize",
"Costa Rica",
"El Salvador",
"Guatemala",
"Honduras",
"Nicaragua",
"Panama",
"Argentina",
"Bolivia",
"Brazil",
"Chile",
"Colombia",
"Ecuador",
"French Guiana",
"Guyana",
"Paraguay",
"Peru",
"Suriname",
"Uruguay",
"Venezuela",
"Alberta",
"Bonaire, Sint Eustatius and Saba",
"British Columbia",
"Falkland Islands (Malvinas)",
"Manitoba",
"New Brunswick",
"Newfoundland and Labrador",
"Northwest Territories",
"Nova Scotia",
"Nunavut",
"Ontario",
"Prince Edward Island",
"Quebec",
"Saint Barthelemy",
"Saint Pierre and Miquelon",
"Saskatchewan",
"St Martin",
"Turks and Caicos Islands",
"Yukon"]]

# %%
americanContinents
# Out:
#                            Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Greenland                       416216           115      11026           6
# Mexico                      1333704122     110850198    5106048      308829
# US                         17333428258     301478150   76354039      901391
# Anguilla                        204843           483       2384           9
# Antigua and Barbuda             907887         23770       6734         127
# ...                                ...           ...        ...         ...
# Saint Pierre and Miquelon        31753             4        966           1
# Saskatchewan                  22817974        252526     121517        1008
# St Martin                      1279205         13989       9442          78
# Turks and Caicos Islands       1164103          8551       5775          34
# Yukon                           284044          2644       3186          18
#
# [64 rows x 4 columns]

# %% [markdown]
# # African Continent

# %%
africanContinent['Total_cases'].max()
# Out:
# 1042778612

# %%
africanContinent['New_cases'].max()
# Out:
# 3616075

# %%
africanContinent['Total_deaths'].max()
# Out:
# 30634506

# %%
africanContinent['New_deaths'].max()
# Out:
# 95773

# %%
highestafricanContinentTotalCases = africanContinent[africanContinent.Total_cases == 1042778612]
highestafricanContinentTotaldeaths = africanContinent[africanContinent.Total_deaths == 30634506]
highestafricanContinentNewCases = africanContinent[africanContinent.New_cases == 3616075]
highestafricanContinentNewdeaths = africanContinent[africanContinent.New_deaths == 95773]

# %%
highestafricanContinentTotalCases
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773

# %%
highestafricanContinentTotaldeaths
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773

# %%
highestafricanContinentNewCases
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773

# %%
highestafricanContinentNewdeaths
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773

# %%
africanContinent['Total_cases'].min()
# Out:
# 1890

# %%
africanContinent['New_cases'].min()
# Out:
# 5

# %%
africanContinent['Total_deaths'].min()
# Out:
# 4

# %%
africanContinent['New_deaths'].min()
# Out:
# 1

# %%
lowestafricanContinentTotalCases = africanContinent[africanContinent.Total_cases == 1890]
lowestafricanContinentTotaldeaths = africanContinent[africanContinent.Total_deaths == 4]
lowestafricanContinentNewCases = africanContinent[africanContinent.New_cases == 5]
lowestafricanContinentNewdeaths = africanContinent[africanContinent.New_deaths == 1]

# %%
lowestafricanContinentTotalCases
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1

# %%
lowestafricanContinentTotaldeaths
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1

# %%
lowestafricanContinentNewCases
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1

# %%
lowestafricanContinentNewdeaths
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1

# %% [markdown]
# # Austrialia Continent

# %%
austrialiaContinent['Total_cases'].max()
# Out:
# 40395860

# %%
austrialiaContinent['New_cases'].max()
# Out:
# 1182732

# %%
austrialiaContinent['Total_deaths'].max()
# Out:
# 508832

# %%
austrialiaContinent['New_deaths'].max()
# Out:
# 2165

# %%
highestaustrialiaContinentTotalCases = austrialiaContinent[austrialiaContinent.Total_cases == 40395860]
highestaustrialiaContinentTotaldeaths = austrialiaContinent[austrialiaContinent.Total_deaths == 508832]
highestaustrialiaContinentNewCases = austrialiaContinent[austrialiaContinent.New_cases == 1182732]
highestaustrialiaContinentNewdeaths = austrialiaContinent[austrialiaContinent.New_deaths == 2165]

# %%
highestaustrialiaContinentTotalCases
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165

# %%
highestaustrialiaContinentTotaldeaths
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165

# %%
highestaustrialiaContinentNewCases
# Out:
#                  Total_cases  Total_deaths  New_cases  New_deaths
# Country
# New South Wales     39330746        125905    1182732        1538

# %%
highestaustrialiaContinentNewdeaths
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165

# %%
austrialiaContinent['Total_cases'].min()
# Out:
# 114

# %%
austrialiaContinent['New_cases'].min()
# Out:
# 1

# %%
austrialiaContinent['Total_deaths'].min()
# Out:
# 0

# %%
austrialiaContinent['New_deaths'].min()
# Out:
# 0

# %%
lowestaustrialiaContinentTotalCases = austrialiaContinent[austrialiaContinent.Total_cases == 114]
lowestaustrialiaContinentTotaldeaths = austrialiaContinent[austrialiaContinent.Total_deaths == 0]
lowestaustrialiaContinentNewCases = austrialiaContinent[austrialiaContinent.New_cases == 1]
lowestaustrialiaContinentNewdeaths = austrialiaContinent[austrialiaContinent.New_deaths == 0]

# %%
lowestaustrialiaContinentTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tonga            114             0          7           0

# %%
lowestaustrialiaContinentTotaldeaths
# Out:
#                   Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Kiribati                 5739             0       1037           0
# Marshall Islands         1898             0          8           0
# Micronesia                380             0          1           0
# Palau                   20331             0       2352           0
# Cook Islands              324             0          2           0
# Samoa                    1603             0         33           0
# Tonga                     114             0          7           0

# %%
lowestaustrialiaContinentNewCases
# Out:
#             Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Micronesia          380             0          1           0

# %%
lowestaustrialiaContinentNewdeaths
# Out:
#                   Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Kiribati                 5739             0       1037           0
# Marshall Islands         1898             0          8           0
# Micronesia                380             0          1           0
# Palau                   20331             0       2352           0
# Cook Islands              324             0          2           0
# Samoa                    1603             0         33           0
# Tonga                     114             0          7           0

# %% [markdown]
# # Europe Continent

# %%
europeContinent['Total_cases'].max()
# Out:
# 2947845708

# %%
europeContinent['New_cases'].max()
# Out:
# 20316971

# %%
europeContinent['Total_deaths'].max()
# Out:
# 63547499

# %%
europeContinent['New_deaths'].max()
# Out:
# 157984

# %%
highesteuropeContinentTotalCases = europeContinent[europeContinent.Total_cases == 2947845708]
highesteuropeContinentTotaldeaths = europeContinent[europeContinent.Total_deaths == 63547499]
highesteuropeContinentNewCases = europeContinent[europeContinent.New_cases == 20316971]
highesteuropeContinentNewdeaths = europeContinent[europeContinent.New_deaths == 157984]

# %%
highesteuropeContinentTotalCases
# Out:
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
highesteuropeContinentTotaldeaths
# Out:
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
highesteuropeContinentNewCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# France    2799923177      51475757   20316971      129861

# %%
highesteuropeContinentNewdeaths
# Out:
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
europeContinent['Total_cases'].min()
# Out:
# 15265

# %%
europeContinent['New_cases'].min()
# Out:
# 29

# %%
europeContinent['Total_deaths'].min()
# Out:
# 0

# %%
europeContinent['New_deaths'].min()
# Out:
# 0

# %%
lowesteuropeContinentTotalCases = europeContinent[europeContinent.Total_cases == 15265]
lowesteuropeContinentTotaldeaths = europeContinent[europeContinent.Total_deaths == 0]
lowesteuropeContinentNewCases = europeContinent[europeContinent.New_cases == 29]
lowesteuropeContinentNewdeaths = europeContinent[europeContinent.New_deaths == 0]

# %%
lowesteuropeContinentTotalCases
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %%
lowesteuropeContinentTotaldeaths
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %%
lowesteuropeContinentNewCases
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %%
lowesteuropeContinentNewdeaths
# Out:
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %% [markdown]
# # Asian Continent

# %%
asianContinent['Total_cases'].max()
# Out:
# 11634884463

# %%
asianContinent['New_cases'].max()
# Out:
# 42080664

# %%
asianContinent['Total_deaths'].max()
# Out:
# 155657094

# %%
asianContinent['New_deaths'].max()
# Out:
# 501115

# %%
highestasianContinentTotalCases = asianContinent[asianContinent.Total_cases == 11634884463]
highestasianContinentTotaldeaths = asianContinent[asianContinent.Total_deaths == 155657094]
highestasianContinentNewCases = asianContinent[asianContinent.New_cases == 42080664]
highestasianContinentNewdeaths = asianContinent[asianContinent.New_deaths == 501115]

# %%
highestasianContinentTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115

# %%
highestasianContinentTotaldeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115

# %%
highestasianContinentNewCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115

# %%
highestasianContinentNewdeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115

# %%
asianContinent['Total_cases'].min()
# Out:
# 737

# %%
asianContinent['New_cases'].min()
# Out:
# 1

# %%
asianContinent['Total_deaths'].min()
# Out:
# 0

# %%
asianContinent['New_deaths'].min()
# Out:
# 0

# %%
lowestasianContinentTotalCases = asianContinent[asianContinent.Total_cases == 737]
lowestasianContinentTotaldeaths = asianContinent[asianContinent.Total_deaths == 0]
lowestasianContinentNewCases = asianContinent[asianContinent.New_cases == 1]
lowestasianContinentNewdeaths = asianContinent[asianContinent.New_deaths == 0]

# %%
lowestasianContinentTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0

# %%
lowestasianContinentTotaldeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Jiangsu       669575             0       1629           0
# Macau          37716             0         78           0
# Ningxia        59706             0        121           0
# Qinghai        14411             0         30           0
# Shanxi        164646             0        267           0
# Tibet            737             0          1           0

# %%
lowestasianContinentNewCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0

# %%
lowestasianContinentNewdeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Jiangsu       669575             0       1629           0
# Macau          37716             0         78           0
# Ningxia        59706             0        121           0
# Qinghai        14411             0         30           0
# Shanxi        164646             0        267           0
# Tibet            737             0          1           0

# %% [markdown]
# # American Continents

# %%
americanContinents['Total_cases'].max()
# Out:
# 17333428258

# %%
americanContinents['New_cases'].max()
# Out:
# 76354039

# %%
americanContinents['Total_deaths'].max()
# Out:
# 301478150

# %%
americanContinents['New_deaths'].max()
# Out:
# 901391

# %%
highestamericanContinentsTotalCases = americanContinents[americanContinents.Total_cases == 17333428258]
highestamericanContinentsTotaldeaths = americanContinents[americanContinents.Total_deaths == 301478150]
highestamericanContinentsNewCases = americanContinents[americanContinents.New_cases == 76354039]
highestamericanContinentsNewdeaths = americanContinents[americanContinents.New_deaths == 901391]

# %%
highestamericanContinentsTotalCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestamericanContinentsTotaldeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestamericanContinentsNewCases
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
highestamericanContinentsNewdeaths
# Out:
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391

# %%
americanContinents['Total_cases'].min()
# Out:
# 17471

# %%
americanContinents['New_cases'].min()
# Out:
# 93

# %%
americanContinents['Total_deaths'].min()
# Out:
# 0

# %%
americanContinents['New_deaths'].min()
# Out:
# 0

# %%
lowestamericanContinentsTotalCases = americanContinents[americanContinents.Total_cases == 17471]
lowestamericanContinentsTotaldeaths = americanContinents[americanContinents.Total_deaths == 0]
lowestamericanContinentsNewCases = americanContinents[americanContinents.New_cases == 93]
lowestamericanContinentsNewdeaths = americanContinents[americanContinents.New_deaths == 0]

# %%
lowestamericanContinentsTotalCases
# Out:
#             Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Montserrat        17471           652        163           1

# %%
lowestamericanContinentsTotaldeaths
# Out:
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0

# %%
lowestamericanContinentsNewCases
# Out:
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0

# %%
lowestamericanContinentsNewdeaths
# Out:
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0

# %%
display(highestafricanContinentTotalCases, highestamericanContinentsTotalCases, highestasianContinentTotalCases, 
           highestaustrialiaContinentTotalCases, highesteuropeContinentTotalCases)
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
display(highestafricanContinentTotaldeaths, highestamericanContinentsTotaldeaths, highestasianContinentTotaldeaths, 
           highestaustrialiaContinentTotaldeaths, highesteuropeContinentTotaldeaths)
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
display(highestafricanContinentNewCases, highestamericanContinentsNewCases, highestasianContinentNewCases, 
           highestaustrialiaContinentNewCases, highesteuropeContinentNewCases)
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115
#                  Total_cases  Total_deaths  New_cases  New_deaths
# Country
# New South Wales     39330746        125905    1182732        1538
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# France    2799923177      51475757   20316971      129861

# %%
display(highestafricanContinentNewdeaths, highestamericanContinentsNewdeaths, highestasianContinentNewdeaths, 
           highestaustrialiaContinentNewdeaths, highesteuropeContinentNewdeaths)
# Out:
#               Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa   1042778612      30634506    3616075       95773
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# US       17333428258     301478150   76354039      901391
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# India    11634884463     155657094   42080664      501115
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Victoria     40395860        508832     908770        2165
#                 Total_cases  Total_deaths  New_cases  New_deaths
# Country
# United Kingdom   2947845708      63547499   17697109      157984

# %%
highest = [highestafricanContinentTotalCases, highestamericanContinentsTotalCases, highestasianContinentTotalCases, 
           highestaustrialiaContinentTotalCases, highesteuropeContinentTotalCases, highestafricanContinentNewdeaths, highestamericanContinentsNewdeaths, highestasianContinentNewdeaths, 
           highestaustrialiaContinentNewdeaths, highesteuropeContinentNewdeaths, highestafricanContinentNewCases, highestamericanContinentsNewCases, highestasianContinentNewCases, 
           highestaustrialiaContinentNewCases, highesteuropeContinentNewCases, highestafricanContinentTotaldeaths, highestamericanContinentsTotaldeaths, highestasianContinentTotaldeaths, 
           highestaustrialiaContinentTotaldeaths, highesteuropeContinentTotaldeaths]

# %%
highest
# Out:
# [              Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  South Africa   1042778612      30634506    3616075       95773,
#           Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  US       17333428258     301478150   76354039      901391,
#           Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  India    11634884463     155657094   42080664      501115,
#            Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  Victoria     40395860        508832     908770        2165,
#                  Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  United Kingdom   2947845708      63547499   17697109      157984,
#                Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  South Africa   1042778612      30634506    3616075       95773,
#           Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  US       17333428258     301478150   76354039      901391,
# ...

# %%
##lowest = covidData[covidData.Country == 'South Africa', 'US', 'India', 'Victoria', 'United Kingdom']
highestCaseData = covidDataCountryGrouped.loc[['South Africa', 'US', 'India', 'Victoria', 'United Kingdom', 'New South Wales',
                                      'France']]

# %%
highestCaseData
# Out:
#                  Total_cases  Total_deaths  New_cases  New_deaths
# Country
# South Africa      1042778612      30634506    3616075       95773
# US               17333428258     301478150   76354039      901391
# India            11634884463     155657094   42080664      501115
# Victoria            40395860        508832     908770        2165
# United Kingdom    2947845708      63547499   17697109      157984
# New South Wales     39330746        125905    1182732        1538
# France            2799923177      51475757   20316971      129861

# %%
print('Pie chart showing the highest total cases in each continent')
highestCaseData['Total_cases'].plot(kind='pie')
# Out:
# Pie chart showing the highest total cases in each continent
# <AxesSubplot:ylabel='Total_cases'>

# %%
print('bar chart showing the highest total death in each continent')
highestCaseData['Total_deaths'].plot(kind='bar', color='r')
# Out:
# bar chart showing the highest total death in each continent
# <AxesSubplot:xlabel='Country'>

# %%
print('bar chart showing the highest new cases in each continent')
highestCaseData['New_cases'].plot(kind='bar', color='b')
# Out:
# bar chart showing the highest new cases in each continent
# <AxesSubplot:xlabel='Country'>

# %%
print('bar chart showing the highest new deaths in each continent')
highestCaseData['New_deaths'].plot(kind='bar', color='y')
# Out:
# bar chart showing the highest new deaths in each continent
# <AxesSubplot:xlabel='Country'>

# %%
display(lowestafricanContinentTotalCases, lowestamericanContinentsTotalCases, lowestasianContinentTotalCases, 
           lowestaustrialiaContinentTotalCases, lowesteuropeContinentTotalCases)
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1
#             Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Montserrat        17471           652        163           1
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %%
display(lowestafricanContinentTotaldeaths, lowestamericanContinentsTotaldeaths, lowestasianContinentTotaldeaths, 
           lowestaustrialiaContinentTotaldeaths, lowesteuropeContinentTotaldeaths)
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Jiangsu       669575             0       1629           0
# Macau          37716             0         78           0
# Ningxia        59706             0        121           0
# Qinghai        14411             0         30           0
# Shanxi        164646             0        267           0
# Tibet            737             0          1           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# ...

# %%
display(lowestafricanContinentNewCases, lowestamericanContinentsNewCases, lowestasianContinentNewCases, 
           lowestaustrialiaContinentNewCases, lowesteuropeContinentNewCases)
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Tibet            737             0          1           0
#           Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Holy See        15265             0         29           0

# %%
display(lowestafricanContinentNewdeaths, lowestamericanContinentsNewdeaths, lowestasianContinentNewdeaths, 
           lowestaustrialiaContinentNewdeaths, lowesteuropeContinentNewdeaths)
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1
#                              Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Falkland Islands (Malvinas)        29537             0         93           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# Jiangsu       669575             0       1629           0
# Macau          37716             0         78           0
# Ningxia        59706             0        121           0
# Qinghai        14411             0         30           0
# Shanxi        164646             0        267           0
# Tibet            737             0          1           0
#          Total_cases  Total_deaths  New_cases  New_deaths
# Country
# ...

# %%
lowest = [lowestafricanContinentTotalCases, lowestamericanContinentsTotalCases, lowestasianContinentTotalCases, 
           lowestaustrialiaContinentTotalCases, lowesteuropeContinentTotalCases, lowestafricanContinentNewdeaths, lowestamericanContinentsNewdeaths, lowestasianContinentNewdeaths, 
           lowestaustrialiaContinentNewdeaths, lowesteuropeContinentNewdeaths, lowestafricanContinentNewCases, lowestamericanContinentsNewCases, lowestasianContinentNewCases, 
           lowestaustrialiaContinentNewCases, lowesteuropeContinentNewCases, lowestafricanContinentTotaldeaths, lowestamericanContinentsTotaldeaths, lowestasianContinentTotaldeaths, 
           lowestaustrialiaContinentTotaldeaths, lowesteuropeContinentTotaldeaths]

# %%
lowest
# Out:
# [                                              Total_cases  Total_deaths  \
#  Country
#  Saint Helena, Ascension and Tristan da Cunha         1890             4
#
#                                                New_cases  New_deaths
#  Country
#  Saint Helena, Ascension and Tristan da Cunha          5           1  ,
#              Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  Montserrat        17471           652        163           1,
#           Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  Tibet            737             0          1           0,
#           Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  Tibet            737             0          1           0,
#            Total_cases  Total_deaths  New_cases  New_deaths
#  Country
#  Holy See        15265             0         29           0,
#                                                Total_cases  Total_deaths  \
#  Country
# ...

# %%
lowestCaseData = covidDataCountryGrouped.loc[[
'Saint Helena, Ascension and Tristan da Cunha',
'Montserrat',
'Tibet',
'Holy See',
'Falkland Islands (Malvinas)',
'Jiangsu',
'Macau',
'Ningxia',
'Qinghai',
'Shanxi'
]]

# %%
lowestCaseData
# Out:
#                                               Total_cases  Total_deaths  \
# Country
# Saint Helena, Ascension and Tristan da Cunha         1890             4
# Montserrat                                          17471           652
# Tibet                                                 737             0
# Holy See                                            15265             0
# Falkland Islands (Malvinas)                         29537             0
# Jiangsu                                            669575             0
# Macau                                               37716             0
# Ningxia                                             59706             0
# Qinghai                                             14411             0
# Shanxi                                             164646             0
#
#                                               New_cases  New_deaths
# Country
# Saint Helena, Ascension and Tristan da Cunha          5           1
# ...

# %%
#covidData

# %%
##male = covidData[covidData.Country == 'Saint Helena, Ascension and Tristan da Cunha','Montserrat','Tibet',
#'Holy See',
#'Falkland Islands (Malvinas)',
#'Jiangsu',
#'Macau',
#'Ningxia',
#'Qinghai','Shanxi']

# %%
sns.barplot(x = "Total_cases", y = "Total_deaths", data = lowestCaseData);

# %%
#kind-----
#bar
#hist
#scatter
#plot
#pie
#, color='r'

# %%
print('Pie chart showing the lowest total cases in each continent')
lowestCaseData['Total_cases'].plot(kind='pie')
# Out:
# Pie chart showing the lowest total cases in each continent
# <AxesSubplot:ylabel='Total_cases'>

# %%
print('bar chart showing the lowest total death in each continent')
lowestCaseData['Total_deaths'].plot(kind='bar', color='r')
# Out:
# bar chart showing the lowest total death in each continent
# <AxesSubplot:xlabel='Country'>

# %%
print('bar chart showing the lowest new cases in each continent')
lowestCaseData['New_cases'].plot(kind='bar', color='b')
# Out:
# bar chart showing the lowest new cases in each continent
# <AxesSubplot:xlabel='Country'>

# %%
print('bar chart showing the lowest new deaths in each continent')
lowestCaseData['New_deaths'].plot(kind='bar', color='y')
# Out:
# bar chart showing the lowest new deaths in each continent
# <AxesSubplot:xlabel='Country'>
